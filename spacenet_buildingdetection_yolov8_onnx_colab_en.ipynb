# %%
# SpaceNet Building Detection - YOLOv8 ONNX

# !pip install rasterio geopandas shapely onnxruntime ultralytics opencv-python tqdm -q
# !apt-get install -y libgdal-dev -q
import os, shutil, subprocess, sys, warnings
import numpy as np
import cv2
from PIL import Image
import rasterio
from rasterio.plot import reshape_as_image
import geopandas as gpd
from sklearn.model_selection import train_test_split
from shapely.geometry import box
from google.colab import drive
from ultralytics import YOLO
from tqdm import tqdm
warnings.filterwarnings("ignore")


# Gerekli paketleri yükle
print("Gerekli paketler yükleniyor...")
import subprocess
import sys

packages = [
    "docutils>=0.20,<0.22",
    "ultralytics",
    "geopandas",
    "shapely",
    "onnxruntime",
    "rasterio",
    "scikit-learn",
    "opencv-python",
    "awscli",
    "tqdm"
]

for package in packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", package, "-q"])
print("Paket kurulumu tamamlandı!")

# GPU kontrolü
try:
    subprocess.run(["nvidia-smi"], check=True)
except FileNotFoundError:
    print("GPU ortamı etkin değil veya nvidia-smi mevcut değil. CPU modunda çalışılıyor.")


# Google Drive'ı bağla
drive.mount('/content/drive')

def normalize_image(img):
    """Görüntüyü normalize et ve kontrastı artır"""
    img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    if len(img.shape) == 3:
        for i in range(3):
            img[:,:,i] = clahe.apply(img[:,:,i].astype(np.uint8))
    else:
        img = clahe.apply(img.astype(np.uint8))
    return img

def resize_image(img, target_size=(640, 640)):
    """Görüntüyü hedef boyuta yeniden boyutlandır"""
    return cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

def enhance_edges(img):
    """Görüntüdeki kenarları belirginleştir"""
    kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    return cv2.filter2D(img, -1, kernel)

def geojson_to_yolo(geojson_path, image_size, out_path):
    """GeoJSON'u YOLO formatına dönüştür"""
    try:
        gdf = gpd.read_file(geojson_path)
        with open(out_path, 'w') as f:
            for _, row in gdf.iterrows():
                geom = row.geometry
                if geom.geom_type == "Polygon":
                    minx, miny, maxx, maxy = geom.bounds
                    x_center = ((minx + maxx) / 2) / image_size[0]
                    y_center = ((miny + maxy) / 2) / image_size[1]
                    width = (maxx - minx) / image_size[0]
                    height = (maxy - miny) / image_size[1]

                    x_center = max(0.005, min(0.995, x_center))
                    y_center = max(0.005, min(0.995, y_center))
                    width = max(0.01, min(0.99, width))
                    height = max(0.01, min(0.99, height))

                    f.write(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        return True
    except Exception as e:
        print(f"Uyarı: {os.path.basename(geojson_path)} dönüştürülemedi: {e}")
        return False

# SpaceNet veri setini indir
spacenet_file = "SN2_buildings_train_AOI_2_Vegas.tar.gz"
extract_dir = "./spacenet"

# Eğer veri seti zaten indirilmiş ve açılmışsa atla
if os.path.exists(extract_dir) and os.path.exists(os.path.join(extract_dir, "AOI_2_Vegas_Train")):
    print("Veri seti zaten mevcut, indirme ve açma işlemleri atlanıyor...")
else:
    print("SpaceNet veri seti indiriliyor...")
    if not os.path.exists("spacenet"):
        os.makedirs("spacenet")

    # Eğer arşiv dosyası zaten varsa indirme işlemini atla
    if not os.path.exists(spacenet_file):
        print("Veri seti arşivi indiriliyor...")
        subprocess.run([
            "aws", "s3", "cp",
            "s3://spacenet-dataset/spacenet/SN2_buildings/tarballs/SN2_buildings_train_AOI_2_Vegas.tar.gz",
            ".",
            "--no-sign-request"
        ], check=True)
    else:
        print("Arşiv dosyası zaten mevcut, indirme işlemi atlanıyor...")

    # Arşivi çıkart
    print("Veri seti arşivden çıkartılıyor...")
    subprocess.run(["tar", "-xf", spacenet_file, "-C", "spacenet"], check=True)
    print("Veri seti hazır!")

    # Arşiv dosyasını sil
    try:
        os.remove(spacenet_file)
        print(f"Arşiv dosyası ({spacenet_file}) başarıyla silindi.")
    except Exception as e:
        print(f"Arşiv dosyası silinirken hata oluştu: {e}")

# Görüntüleri işle
src_dir = "./spacenet/AOI_2_Vegas_Train/RGB-PanSharpen"
dst_dir = "./spacenet/RGB-Converted"
label_dir = "./spacenet/labels"

os.makedirs(dst_dir, exist_ok=True)
os.makedirs(label_dir, exist_ok=True)

# Görüntüleri dönüştür
files = [f for f in os.listdir(src_dir) if f.endswith('.tif') and "AOI_2_Vegas_img" in f]
converted = 0
skipped = 0

print("\nGörüntüler işleniyor...")
for file in tqdm(files, desc="Görüntü İşleme"):
    img_id = file.split("RGB-PanSharpen_")[-1].replace(".tif", "")
    geojson_path = os.path.join("./spacenet/AOI_2_Vegas_Train/geojson/buildings", f"buildings_{img_id}.geojson")

    if not os.path.exists(geojson_path):
        skipped += 1
        continue

    src_path = os.path.join(src_dir, file)
    try:
        with rasterio.open(src_path) as src:
            rgb = src.read([1, 2, 3])
            img = reshape_as_image(rgb)
            img = normalize_image(img)
            img = enhance_edges(img)
            img = resize_image(img)

            out_path = os.path.join(dst_dir, f"{img_id}.jpg")
            Image.fromarray(img.astype(np.uint8)).save(out_path, quality=95)
            converted += 1
    except Exception as e:
        print(f"\nUyarı: {file} dönüştürülemedi: {e}")
        skipped += 1

print(f"\nGörüntü Dönüştürme İstatistikleri:")
print(f"Başarılı: {converted} görüntü")
print(f"Atlanan: {skipped} görüntü")

# Etiketleri dönüştür
image_size = None
for img_file in os.listdir(dst_dir):
    if img_file.endswith('.jpg'):
        with Image.open(os.path.join(dst_dir, img_file)) as img:
            image_size = img.size
            print(f"\nReferans görüntü boyutu: {image_size}")
            break

if image_size:
    converted_labels = 0
    failed_labels = 0

    print("\nEtiketler dönüştürülüyor...")
    for img_file in tqdm(os.listdir(dst_dir), desc="Etiket Dönüştürme"):
        if img_file.endswith('.jpg'):
            img_id = img_file.replace('.jpg', '')
            geojson_path = os.path.join("./spacenet/AOI_2_Vegas_Train/geojson/buildings", f"buildings_{img_id}.geojson")
            label_path = os.path.join(label_dir, f"{img_id}.txt")

            if geojson_to_yolo(geojson_path, image_size, label_path):
                converted_labels += 1
            else:
                failed_labels += 1

    print(f"\nEtiket Dönüştürme İstatistikleri:")
    print(f"Başarılı: {converted_labels} etiket")
    print(f"Başarısız: {failed_labels} etiket")

# Veri setini hazırla
all_images = []
for img_file in os.listdir(dst_dir):
    if img_file.endswith('.jpg'):
        img_id = img_file.replace('.jpg', '')
        label_path = os.path.join(label_dir, f"{img_id}.txt")
        if os.path.exists(label_path) and os.path.getsize(label_path) > 0:
            all_images.append(img_file)

if len(all_images) > 0:
    # Eğitim/doğrulama ayrımı
    train_imgs, val_imgs = train_test_split(all_images, test_size=0.2, random_state=42)

    # Dizinleri oluştur
    train_img_dir = "./spacenet/images/train"
    val_img_dir = "./spacenet/images/val"
    train_label_dir = "./spacenet/labels/train"
    val_label_dir = "./spacenet/labels/val"

    for dir_path in [train_img_dir, val_img_dir, train_label_dir, val_label_dir]:
        os.makedirs(dir_path, exist_ok=True)

    # Dosyaları kopyala
    def copy_files(images, img_dir, label_dir_src, label_dir_dst):
        copied = 0
        print(f"\nDosyalar kopyalanıyor...")
        for img_file in tqdm(images, desc="Dosya Kopyalama"):
            try:
                img_id = img_file.replace('.jpg', '')
                shutil.copy(
                    os.path.join(dst_dir, img_file),
                    os.path.join(img_dir, img_file)
                )
                shutil.copy(
                    os.path.join(label_dir_src, f"{img_id}.txt"),
                    os.path.join(label_dir_dst, f"{img_id}.txt")
                )
                copied += 1
            except Exception as e:
                print(f"\nUyarı: {img_file} kopyalanamadı: {e}")
        return copied

    train_copied = copy_files(train_imgs, train_img_dir, label_dir, train_label_dir)
    val_copied = copy_files(val_imgs, val_img_dir, label_dir, val_label_dir)

    print(f"\nVeri Seti Ayrım İstatistikleri:")
    print(f"Eğitim: {train_copied} görüntü")
    print(f"Doğrulama: {val_copied} görüntü")

# YOLOv8 yapılandırma dosyasını oluştur
yaml_content = f"""
# YOLOv8 yapılandırması
path: {os.path.abspath("./spacenet")}  # veri seti kök dizini
train: images/train  # eğitim görüntüleri
val: images/val  # doğrulama görüntüleri

# Sınıflar
nc: 1  # sınıf sayısı
names: ['building']  # sınıf isimleri

# Eğitim parametreleri
epochs: 50
batch: 16
imgsz: 640
optimizer: AdamW
lr0: 0.001
lrf: 0.01
momentum: 0.937
weight_decay: 0.0005
warmup_epochs: 3.0
warmup_momentum: 0.8
warmup_bias_lr: 0.1
box: 7.5
cls: 0.5
dfl: 1.5
fl_gamma: 0.0
label_smoothing: 0.0
nbs: 64
hsv_h: 0.015
hsv_s: 0.7
hsv_v: 0.4
translate: 0.1
scale: 0.5
shear: 0.0
perspective: 0.0
flipud: 0.0
fliplr: 0.5
mosaic: 1.0
mixup: 0.0
copy_paste: 0.0
"""

with open("spacenet.yaml", "w") as f:
    f.write(yaml_content)
print("spacenet.yaml başarıyla oluşturuldu.")

# YOLOv8 modelini egit
from ultralytics import YOLO

print("\nModel Eğitim Parametreleri:")
print("  - Model: YOLOv8n")
print("  - Epochs: 50")
print("  - Görüntü boyutu: 640x640")
print("  - Batch size: 16")
print("  - Optimizer: AdamW")
print("  - Learning rate: 0.001")

model = YOLO("yolov8n.pt")
model.train(
    data="spacenet.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name='spacenet_buildings',
    optimizer='AdamW',
    lr0=0.001
)

# ONNX'e dönüştür ve test et
print("\nModel ONNX formatına dönüştürülüyor...")
model.export(format="onnx")
print("ONNX model oluşturuldu: runs/detect/spacenet_buildings/weights/best.onnx")

print("\nONNX model test ediliyor...")
import onnxruntime
session = onnxruntime.InferenceSession("runs/detect/spacenet_buildings/weights/best.onnx")
input_name = session.get_inputs()[0].name
dummy_input = np.random.rand(1, 3, 640, 640).astype(np.float32)
output = session.run(None, {input_name: dummy_input})
print("ONNX model testi başarılı!")

# Sonuçları Google Drive'a kaydet
print("\nSonuçlar Google Drive'a kaydediliyor...")
shutil.copytree("runs/detect/spacenet_buildings", "/content/drive/MyDrive/spacenet_buildings")
shutil.copy("runs/detect/spacenet_buildings/weights/best.onnx", "/content/drive/MyDrive/best.onnx")
print("Sonuçlar Google Drive'a başarıyla kaydedildi!")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libgdal-dev is already the newest version (3.8.4+dfsg-1~jammy0).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Gerekli paketler yükleniyor...
# Paket kurulumu tamamlandı!
# GPU ortamı etkin değil veya nvidia-smi mevcut değil. CPU modunda çalışılıyor.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Veri seti zaten mevcut, indirme ve açma işlemleri atlanıyor...
#
# Görüntüler işleniyor...
# Görüntü İşleme: 100%|██████████| 3851/3851 [03:12<00:00, 19.97it/s]
# Görüntü Dönüştürme İstatistikleri:
# Başarılı: 3851 görüntü
# Atlanan: 0 görüntü
#
# Referans görüntü boyutu: (640, 640)
#
# Etiketler dönüştürülüyor...
# Etiket Dönüştürme: 100%|██████████| 3851/3851 [00:33<00:00, 116.35it/s]
# Etiket Dönüştürme İstatistikleri:
# Başarılı: 3851 etiket
# Başarısız: 0 etiket
#
# Dosyalar kopyalanıyor...
# Dosya Kopyalama: 100%|██████████| 2888/2888 [00:11<00:00, 252.76it/s]
# Dosyalar kopyalanıyor...
# Dosya Kopyalama: 100%|██████████| 722/722 [00:02<00:00, 276.38it/s]
# Veri Seti Ayrım İstatistikleri:
# Eğitim: 2888 görüntü
# Doğrulama: 722 görüntü
# spacenet.yaml başarıyla oluşturuldu.
#
# Model Eğitim Parametreleri:
#   - Model: YOLOv8n
#   - Epochs: 50
#   - Görüntü boyutu: 640x640
#   - Batch size: 16
#   - Optimizer: AdamW
#   - Learning rate: 0.001
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 68.1MB/s]
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (AMD EPYC 7B12)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=spacenet.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=spacenet_buildings, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/spacenet_buildings, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 13.8MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5420.9±1342.7 MB/s, size: 383.1 KB)
# train: Scanning /content/spacenet/labels/train... 2888 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2888/2888 [00:01<00:00, 2501.37it/s]
# train: /content/spacenet/images/train/AOI_2_Vegas_img1.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img10.jpg: 24 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1000.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1003.jpg: 5 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1006.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1007.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1009.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img101.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1010.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1015.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1016.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1017.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1018.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1021.jpg: 37 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1023.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1025.jpg: 25 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1028.jpg: 6 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1029.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1030.jpg: 61 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1032.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1034.jpg: 3 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1038.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1042.jpg: 42 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1048.jpg: 21 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1049.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1051.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1053.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1056.jpg: 30 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img106.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1061.jpg: 76 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1062.jpg: 67 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1063.jpg: 61 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1065.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1070.jpg: 58 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1073.jpg: 53 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1075.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1080.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1082.jpg: 62 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1086.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1088.jpg: 55 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1089.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img109.jpg: 52 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1090.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1092.jpg: 42 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1097.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img110.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1102.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1103.jpg: 3 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1104.jpg: 6 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1105.jpg: 60 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1106.jpg: 63 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1107.jpg: 51 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1110.jpg: 56 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1115.jpg: 13 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1117.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1119.jpg: 47 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1120.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1122.jpg: 24 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1124.jpg: 49 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1126.jpg: 59 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1127.jpg: 62 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img113.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1130.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1134.jpg: 54 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1136.jpg: 67 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1139.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1141.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1142.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1143.jpg: 53 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1144.jpg: 40 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1145.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1147.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1151.jpg: 30 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1152.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1156.jpg: 55 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1158.jpg: 54 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img116.jpg: 52 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1161.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1162.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1163.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1167.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img117.jpg: 24 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1170.jpg: 62 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1171.jpg: 46 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1173.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1176.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1179.jpg: 16 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1181.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1185.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1190.jpg: 53 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1194.jpg: 12 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1196.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1197.jpg: 47 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1201.jpg: 55 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1202.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1204.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1205.jpg: 21 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1209.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1210.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1211.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1213.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1214.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1215.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1216.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1217.jpg: 49 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1219.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1222.jpg: 51 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1225.jpg: 50 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1226.jpg: 43 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1227.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1233.jpg: 58 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1234.jpg: 55 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1236.jpg: 57 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1238.jpg: 54 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1239.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1242.jpg: 13 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1244.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1245.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1246.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1247.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1248.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1250.jpg: 52 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1251.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1252.jpg: 61 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1255.jpg: 42 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1258.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1259.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1262.jpg: 76 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1264.jpg: 68 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1267.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1270.jpg: 28 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1272.jpg: 47 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1274.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1275.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1276.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1279.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1280.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1281.jpg: 47 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1284.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1288.jpg: 69 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img129.jpg: 11 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1290.jpg: 41 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1293.jpg: 37 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1294.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1295.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1299.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img13.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1300.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1301.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1305.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1308.jpg: 30 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1310.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1314.jpg: 54 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1316.jpg: 53 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1318.jpg: 49 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img132.jpg: 7 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1323.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1324.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1325.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1327.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1328.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1331.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1332.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1336.jpg: 23 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1339.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1341.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1342.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1343.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img135.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1350.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1352.jpg: 46 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1354.jpg: 3 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1357.jpg: 56 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1358.jpg: 63 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1359.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1366.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1369.jpg: 12 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1370.jpg: 13 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1372.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1376.jpg: 57 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1377.jpg: 61 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1378.jpg: 46 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img138.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1380.jpg: 54 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1382.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1384.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1385.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1388.jpg: 58 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1389.jpg: 75 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img139.jpg: 23 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1391.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1392.jpg: 56 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1393.jpg: 56 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1396.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1397.jpg: 50 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1398.jpg: 66 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img14.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1402.jpg: 6 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1404.jpg: 41 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1405.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img141.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1410.jpg: 66 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1412.jpg: 23 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1413.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1414.jpg: 57 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1419.jpg: 59 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1420.jpg: 64 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1423.jpg: 28 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1436.jpg: 15 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1437.jpg: 41 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img144.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1440.jpg: 25 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1442.jpg: 24 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1443.jpg: 63 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1451.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1452.jpg: 7 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1457.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1463.jpg: 21 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1466.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1469.jpg: 46 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img148.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1481.jpg: 57 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1484.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1485.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1486.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1488.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1489.jpg: 10 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img149.jpg: 7 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1492.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1497.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img150.jpg: 43 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1500.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1502.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1503.jpg: 42 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1504.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1505.jpg: 54 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1509.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img151.jpg: 50 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1511.jpg: 51 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1513.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1514.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1518.jpg: 37 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1523.jpg: 52 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1529.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img153.jpg: 62 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1530.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1532.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1533.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1535.jpg: 30 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1537.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1539.jpg: 40 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img154.jpg: 64 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1540.jpg: 33 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1541.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1542.jpg: 58 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1544.jpg: 53 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1546.jpg: 43 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1548.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1552.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1553.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1554.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1557.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1558.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1559.jpg: 10 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img156.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1561.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1562.jpg: 55 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1563.jpg: 64 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1564.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1569.jpg: 40 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img157.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1571.jpg: 7 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1573.jpg: 57 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1574.jpg: 49 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1575.jpg: 28 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1576.jpg: 40 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1578.jpg: 57 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1579.jpg: 66 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1583.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1584.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1585.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1588.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1592.jpg: 40 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1593.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1594.jpg: 10 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1601.jpg: 15 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1603.jpg: 5 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1604.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1606.jpg: 24 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1609.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1612.jpg: 10 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1614.jpg: 15 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1615.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1620.jpg: 11 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1621.jpg: 25 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1622.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1624.jpg: 41 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1625.jpg: 51 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1626.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1627.jpg: 28 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1632.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1634.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1636.jpg: 63 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1638.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1639.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img164.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1649.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img165.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1654.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1655.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1658.jpg: 30 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1659.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img166.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1660.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1662.jpg: 43 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1663.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1669.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img167.jpg: 31 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1671.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1672.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1673.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1674.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1675.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1676.jpg: 21 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1678.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1681.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1683.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1684.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1687.jpg: 33 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1689.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img169.jpg: 25 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1690.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1691.jpg: 30 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1695.jpg: 5 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1696.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1697.jpg: 6 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1699.jpg: 49 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img170.jpg: 33 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1704.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1706.jpg: 16 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1709.jpg: 36 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1710.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1714.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1724.jpg: 46 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1725.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1727.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img173.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1730.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1731.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1733.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1734.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1735.jpg: 15 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img174.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1742.jpg: 23 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1743.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1746.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1749.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img175.jpg: 42 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1750.jpg: 43 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1751.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1754.jpg: 47 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1755.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1757.jpg: 11 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1762.jpg: 67 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1765.jpg: 49 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1768.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1770.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1771.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1772.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1773.jpg: 5 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1774.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1779.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1782.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1784.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1787.jpg: 13 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img179.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1791.jpg: 5 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1796.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img180.jpg: 35 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1802.jpg: 19 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1803.jpg: 13 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1808.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1809.jpg: 46 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img181.jpg: 34 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1810.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1811.jpg: 42 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1812.jpg: 44 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1813.jpg: 41 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1814.jpg: 41 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1816.jpg: 41 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1819.jpg: 10 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img182.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1822.jpg: 37 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1826.jpg: 55 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1829.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img183.jpg: 51 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1834.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1836.jpg: 7 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1845.jpg: 12 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1846.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1847.jpg: 12 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1849.jpg: 5 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img185.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1853.jpg: 7 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1854.jpg: 17 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1855.jpg: 15 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1856.jpg: 8 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1862.jpg: 10 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1863.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1864.jpg: 20 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1867.jpg: 16 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1868.jpg: 24 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1870.jpg: 23 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1873.jpg: 50 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1875.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1878.jpg: 39 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1879.jpg: 32 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1881.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1885.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1886.jpg: 48 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img189.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1894.jpg: 6 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1898.jpg: 7 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img190.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1900.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1901.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1906.jpg: 15 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1912.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1915.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1918.jpg: 9 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1920.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1921.jpg: 10 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1924.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1926.jpg: 18 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1927.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1928.jpg: 15 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1930.jpg: 22 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1932.jpg: 26 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1938.jpg: 45 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img194.jpg: 27 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1941.jpg: 56 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1942.jpg: 38 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1948.jpg: 64 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1949.jpg: 58 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img195.jpg: 21 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1951.jpg: 64 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1952.jpg: 29 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1957.jpg: 6 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img196.jpg: 12 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1960.jpg: 16 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1961.jpg: 6 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1963.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1965.jpg: 1 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1968.jpg: 14 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1973.jpg: 2 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1974.jpg: 4 duplicate labels removed
# train: /content/spacenet/images/train/AOI_2_Vegas_img1976.jpg: 22 duplicate labels removed
# ...
# val: /content/spacenet/images/val/AOI_2_Vegas_img5007.jpg: 3 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5011.jpg: 4 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5013.jpg: 48 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img505.jpg: 29 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5068.jpg: 7 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img507.jpg: 21 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5080.jpg: 47 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5087.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img509.jpg: 49 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5091.jpg: 6 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5094.jpg: 39 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5108.jpg: 18 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5115.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5140.jpg: 32 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5141.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5151.jpg: 11 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5152.jpg: 13 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5170.jpg: 8 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5177.jpg: 39 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5179.jpg: 25 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5182.jpg: 17 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5199.jpg: 21 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5208.jpg: 13 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5222.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5224.jpg: 42 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5225.jpg: 28 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5233.jpg: 15 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5235.jpg: 70 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5247.jpg: 6 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img525.jpg: 23 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5253.jpg: 4 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5270.jpg: 18 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5276.jpg: 80 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5277.jpg: 27 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5289.jpg: 3 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5292.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5295.jpg: 7 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img53.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5303.jpg: 46 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5305.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5321.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5327.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img534.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5352.jpg: 3 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5364.jpg: 59 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5387.jpg: 39 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5395.jpg: 33 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5409.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5422.jpg: 8 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5428.jpg: 6 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5434.jpg: 62 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5437.jpg: 56 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5440.jpg: 46 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img547.jpg: 7 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5476.jpg: 19 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img548.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5488.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5496.jpg: 13 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5499.jpg: 8 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5516.jpg: 21 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img552.jpg: 20 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5521.jpg: 49 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5523.jpg: 52 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5537.jpg: 33 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5546.jpg: 29 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5593.jpg: 33 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5597.jpg: 56 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5607.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5631.jpg: 56 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5664.jpg: 49 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5669.jpg: 31 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5675.jpg: 65 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5700.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5731.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5736.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5744.jpg: 48 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5756.jpg: 3 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5762.jpg: 57 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5766.jpg: 3 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5777.jpg: 16 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5781.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5788.jpg: 47 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5790.jpg: 34 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5798.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5803.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5807.jpg: 3 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img581.jpg: 15 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5817.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5820.jpg: 29 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5834.jpg: 8 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5836.jpg: 26 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5840.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5852.jpg: 37 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5892.jpg: 10 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5896.jpg: 17 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5897.jpg: 21 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5912.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img592.jpg: 37 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5945.jpg: 47 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5948.jpg: 42 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5959.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5965.jpg: 30 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5989.jpg: 10 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img5998.jpg: 15 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6000.jpg: 21 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6004.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6013.jpg: 23 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6019.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6025.jpg: 59 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6029.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6062.jpg: 29 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6067.jpg: 31 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6078.jpg: 37 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6084.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6089.jpg: 48 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6103.jpg: 54 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6105.jpg: 28 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img612.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6130.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6131.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img614.jpg: 36 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6144.jpg: 53 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6148.jpg: 39 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6157.jpg: 60 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6180.jpg: 46 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6189.jpg: 3 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6202.jpg: 9 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img621.jpg: 12 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6219.jpg: 32 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img623.jpg: 29 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6230.jpg: 33 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6248.jpg: 43 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6250.jpg: 38 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6261.jpg: 48 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6262.jpg: 34 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6280.jpg: 8 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6294.jpg: 8 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6305.jpg: 22 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6308.jpg: 50 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img631.jpg: 65 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6321.jpg: 42 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6322.jpg: 49 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6332.jpg: 6 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6336.jpg: 29 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6341.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6357.jpg: 1 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6374.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img6387.jpg: 6 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img64.jpg: 45 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img645.jpg: 21 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img666.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img674.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img681.jpg: 31 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img69.jpg: 44 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img701.jpg: 32 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img714.jpg: 17 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img718.jpg: 15 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img755.jpg: 13 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img771.jpg: 12 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img788.jpg: 6 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img798.jpg: 7 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img810.jpg: 30 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img818.jpg: 26 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img819.jpg: 35 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img823.jpg: 16 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img843.jpg: 67 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img845.jpg: 27 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img882.jpg: 2 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img884.jpg: 38 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img889.jpg: 33 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img898.jpg: 60 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img899.jpg: 58 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img904.jpg: 15 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img917.jpg: 17 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img959.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img961.jpg: 5 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img981.jpg: 6 duplicate labels removed
# val: /content/spacenet/images/val/AOI_2_Vegas_img992.jpg: 30 duplicate labels removed
# val: New cache created: /content/spacenet/labels/val.cache
# Plotting labels to runs/detect/spacenet_buildings/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/spacenet_buildings
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      4.265      10.68     0.9469         78        640:  43%|████▎     | 78/181 [12:40<16:18,  9.50s/it]
